# %% [markdown]
# # Experimental data (15%Tm,  85%Yb)

# %%
C2 = 15

blue15 = [3, 7.5, 2.5*10, 9*10, 2.3*10**2, 2.5*10**2, 5.4*10**2, 7.5*10**2, 9*10**2, 1*10**3, 1.2*10**3, 1.4*10**3]
P980_blue15 = [4.4*10**3, 5*10**3, 6*10**3, 7.5*10**3, 9.1*10**3, 1.1*10**4, 1.4*10**4, 1.7*10**4, 2*10**4, 2.3*10**4, 2.7*10**4, 3*10**4]

NIR15 = [3*10, 6*10, 1.4*10**2, 6*10**2, 8*10**2, 1.4*10**3, 2*10**3, 2.6*10**3, 3.5*10**3, 4*10**3, 4.5*10**3, 4.9*10**3, 5*10**3, 5*10**3, 5*10**3]
P980_NIR15 = [1.2*10**3, 1.8*10**3, 2.8*10**3, 4.4*10**3, 5*10**3, 6*10**3, 7.5*10**3, 9.1*10**3, 1.1*10**4, 1.4*10**4, 1.7*10**4, 2*10**4, 2.3*10**4, 2.7*10**4, 3*10**4]


P980_NIR = P980_NIR15

P980_blue = P980_blue15

NIR_exp = NIR15

blue_exp = blue15

# %% [markdown]
# # define global variables

# %%
epsilon = 1e-1 # something to change

learning_rate1 = 5 # something to change
    
learning_rate2 = 5 # something to change

small_threshold = 1e-2 # something to change

c1_range = [(50, 300)] 

c2_range = [(1, 3)]

c3_range = [(1, 4)]

c4_range = [(1, 5)]

k31_range = [(1, 6)]

k41_range = [(1, 7)]

k51_range = [(1, 8)]

parameter_ranges = c1_range + c2_range + c3_range + c4_range + k31_range + k41_range + k51_range


dic = {'c1': 0, 'c2': 1, 'c3': 2, 'c4': 3, 'k31': 4, 'k41': 5, 'k51': 6}


x = C2

# %%
import numpy as np
import json
from tqdm import tqdm
from scipy.optimize import minimize
from scipy.integrate import odeint


a21 = 1
a31 = 0.27
a32 = 0.73

a41 = 0.18
a42 = 0.24
a43 = 0.58

a51 = 0.24
a52 = 0.23
a53 = 0.2
a54 = 0.33

W2 = 63000
W3 = 20000
W4 = 15000
W5 = 33000
Ws2 = 8000



def system(state, t, x, P980, c1, c2, c3, c4, k31, k41, k51):

    ns2, n1, n2, n3, n4, n5 = state

    #ns2
    ms2 = 1.23*P980*(37*(100-x)-ns2) - Ws2*ns2 - (c1*n1+c2*n2+c3*n3+c4*n4)*ns2  # ns1 = total_Yb - ns2

    # n1
    m1 = -c1*n1*ns2 + a21*W2*n2 + a31*W3*n3 + a41*W4*n4 + a51*W5*n5 - k41*n1*n4 - k31*n1*n3 - k51*n5*n1

    # n2
    m2 = c1*n1*ns2 - c2*n2*ns2 - a21*W2*n2 + a32*W3*n3 + a42*W4*n4 + a52*W5*n5 + k41*n1*n4 + 2*k31*n1*n3

    # n3
    m3 = c2*n2*ns2 - c3*n3*ns2 - (a31+a32)*W3*n3 + a43*W4*n4 + a53*W5*n5 + 2*k51*n1*n5 + k41*n1*n4 - k31*n1*n3

    # n4
    m4 = c3*n3*ns2 - c4*n4*ns2 - (a43+a42+a41)*W4*n4 + a54*W5*n5 - k41*n1*n4

    # n5
    m5 = c4*n4*ns2 - (a54+a53+a52+a51)*W5*n5 - k51*n1*n5


    return [ms2, m1, m2, m3, m4, m5]


def compute_blue_for_x(x, P980, c1, c2, c3, c4, k31, k41, k51):


    y = 37 * x
    state0 = [0, y, 0, 0, 0, 0]
    t = np.arange(0.0, 0.001, 0.000001)
    state = odeint(system, state0, t, args=(x, P980, c1, c2, c3, c4, k31, k41, k51))
    blue_total = a41 * W4 * state[:, 4][-1] + a52 * W5 * state[:, 5][-1]

    return blue_total

def compute_NIR_for_x(x, P980, c1, c2, c3, c4, k31, k41, k51):

    y = 37 * x
    state0 = [0, y, 0, 0, 0, 0]
    t = np.arange(0.0, 0.001, 0.000001)
    state = odeint(system, state0, t, args=(x, P980, c1, c2, c3, c4, k31, k41, k51))
    NIR = a31 * W3 * state[:, 3][-1]

    return NIR

# %% [markdown]
# # cost function(SSE)

# %%
def cost_function(params):
    
    c1, c2, c3, c4, k31, k41, k51 = params
    
    cost = 0
    
    for P980, exp_nir in zip(P980_NIR, NIR_exp):
        nir = compute_NIR_for_x(x, P980, c1, c2, c3, c4, k31, k41, k51)
        cost_NIR = ((nir - exp_nir)/exp_nir)**2
        cost += cost_NIR
        
        
    for P980, exp_blue in zip(P980_blue, blue_exp):
        blue = compute_blue_for_x(x, P980, c1, c2, c3, c4, k31, k41, k51)
        cost_blue = ((blue - exp_blue)/exp_blue)**2
        cost += cost_blue    

    return cost / 10000

# %% [markdown]
# # Numerical difference: central difference

# %%
def gradient(current_params, index):
    
    
    epsilon = 1e-3
    
    params_plus = current_params.copy()
    params_minus = current_params.copy()
    params_plus[index] += epsilon
    params_minus[index] -= epsilon
    grad = (cost_function(params_plus) - cost_function(params_minus)) / (2 * epsilon)
        
    return grad

# %% [markdown]
# # There are four functions defined below:
#
# `move_through1`
#
# `move_through2`
#
# `move_through3`
#
# `move_through4`
#
# They can make the `grad` pass through the peak from two directions, and pass through the valley from two directions, by moving a tiny proper step each time.

# %%
def move_through1(grad, current_params, index):
    
    while grad<small_threshold:
        
        current_params[index] +=  1e-1    
        grad = gradient(current_params, index)
        
    return current_params

# %%
def move_through2(grad, current_params, index):
    

    while grad > small_threshold*-1:
        
        current_params[index] -=  1e-1  
        grad = gradient(current_params, index)
        
    return current_params

# %%
def move_through3(grad, current_params, index):
    
    while grad<small_threshold:
        
        current_params[index] -=  1e-1    
        grad = gradient(current_params, index)
        
    return current_params

# %%
def move_through4(grad, current_params, index):
    

    while grad > small_threshold*-1:
        
        current_params[index] +=  1e-1  
        grad = gradient(current_params, index)
        
    return current_params

# %% [markdown]
# # `gradient_descent_boosting1`
#
# Firstly descent, after reaches the valley, then boosting.

# %%
# input parameters: [c1, c2, c3, c4, k31, k41, k51], and p: c1...

def gradient_descent_boosting1(params, p):
    

   
    
    cost1 = []
    
    All_min1 = []  # To store the minimum cost and associated parameters
    
    index = dic[p]
    
    # Initialize the parameter values
    current_params = params.copy()

    while True:
        
          
        boosting = False  # Flag to switch between gradient descent and boosting

        # Check if current_params are within the specified parameter ranges
        
        descent=0
        while not boosting:
            
                descent+=1
            
                grad = gradient(current_params, index)
                print('\n')
                print('Now descent')
                
                print(f'gradient with respect to {p} = {grad}')
                
                
                if grad < 0:
                    flag = -1
                    print(f'grad={grad} <0, move forward')
                    
                else:
                    flag = 1
                    print(f'grad={grad} >0, move backward')

                # Update parameters using gradient descent
                m = current_params[index]
                print(f'before update, this parameter={current_params[index]}')
                current_params[index] -= learning_rate1 * grad
                print(f'after update, this parameter={current_params[index]}')
                print(f'difference = {abs(current_params[index]-m)}')
                
                

                # Check if a valley (gradient close to zero) is reached
                if abs(grad) < small_threshold:
                    # Calculate the cost with the newest parameters
                    print(f'abs_grad={abs(grad)}<{small_threshold}')
                    valley = cost_function(current_params)
                    cost1.append(valley)
                    All_min1.append({'min values': valley, 'parameters': current_params.copy()})
                    boosting = True  # Switch to gradient boosting phase
                    
                    break

     
        (min_val, max_val) = parameter_ranges[index]
        current_val = current_params[index]
        if not (min_val <= current_val <= max_val):
            print(f'This parameter {p} now is {current_val}, which reaches its bound')
            break  


        # Perform gradient boosting until a peak is reached (gradient close to zero)
        
        print('\n')
        print(f'after {descent} descent times, switch from descent to boosting')
        
        boost_times=0
        
        while boosting:
            
            boost_times+=1
            
            if flag == -1:
                current_params=move_through1(grad, current_params, index)
                
            elif flag == 1:
                current_params=move_through2(grad, current_params, index)
                
                
            # Update parameters using boosting (e.g., gradient boosting or another boosting algorithm)
            
            print('pass throuth the valley, now boosting')
    
            grad = gradient(current_params, index)
            
            current_params[index] += learning_rate2 * grad

            # Check if a peak (gradient close to zero) is reached
            if abs(grad) < small_threshold:
                print(f'after {boost_times} boost times, now reaches the peak, switch to descent')
                break
                
                

        (min_val, max_val) = parameter_ranges[index]
        current_val = current_params[index]
        if not (min_val <= current_val <= max_val):
            print(f'This parameter {p} now is {current_val}, which reaches its bound')
            break  

    return All_min1

# %% [markdown]
# # `gradient_descent_boosting2`
#
# Firstly boosting, after reaches the peak, then descent.

# %%
def gradient_descent_boosting2(params, p):
    
    All_min2 = []  # To store the minimum cost and associated parameters
    
    index = dic[p]
    
    cost2 = []
        

    # Initialize the parameter values
    current_params = params.copy()

    while True:
        
          
        boosting = True  # Start with gradient boosting (climbing)
        peak = None  # Placeholder for the peak

        # Check if current_params are within the specified parameter ranges
      
        boost_times=0
        
        while boosting:
            
            boost_times+=1
            
            
            print('Now boosting')
            grad = gradient(current_params, index)
            
            if grad > 0:
                flag = 1  # Moving in the positive direction (climbing)
                print(f'grad={grad} >0, move forward')
            else:
                flag = -1  # Moving in the negative direction (descending)
                print(f'grad={grad} <0, move backward')
                
                # Update parameters using gradient descent
            m = current_params[index]
            print(f'before update, this parameter={current_params[index]}')
            current_params[index] += learning_rate2 * grad
            print(f'after update, this parameter={current_params[index]}')
            print(f'difference = {abs(current_params[index]-m)}')


            # Check if a peak (gradient close to zero or negative) is reached
            if abs(grad) < small_threshold:
                
                print(f'after {boost_times} boost times, now reaches the peak, switch to descent')
                # Record the cost with the current parameters as a potential peak
                boosting = False  # Switch to gradient descent phase
                
                break
                
                
        (min_val, max_val) = parameter_ranges[index]
        current_val = current_params[index]
        if not (min_val <= current_val <= max_val):
            print(f'This parameter {p} now is {current_val}, which reaches its bound')
            break  

        # Perform gradient descent until a valley is reached (gradient close to zero)
        
        print('\n')
        print('Switch from boosting to descent')
        
        descent = 0
        while not boosting:
            
            descent+=1
            
            if flag == 1:
                current_params=move_through4(grad, current_params, index)
                
            elif flag == -1:
                current_params=move_through3(grad, current_params, index)
                
            print('pass throuth the peak, now descent')

            
            grad = gradient(current_params, index)
            print('\n')
            print(f'gradient with respect to {p} = {grad}')
    

            # Update parameters using gradient descent
            current_params[index] -= learning_rate1 * grad
            

            # Check if a valley (gradient close to zero) is reached
            if abs(grad) < small_threshold:
               
                print(f'abs_grad={abs(grad)}<{small_threshold}')
                valley = cost_function(current_params)
                cost2.append(valley)
                All_min2.append({'min values': valley, 'parameters': current_params.copy()})
                boosting = True  # Switch to gradient boosting phase
                
                break

                
        (min_val, max_val) = parameter_ranges[index]
        current_val = current_params[index]
        if not (min_val <= current_val <= max_val):
            print(f'This parameter {p} now is {current_val}, which reaches its bound')
            break  

    return All_min2

# %% [markdown]
# # Give the initial values of the seven parameters, then take one as an example. (eg. `c1`)

# %%
initial_params = [2, -1, 1, 1.5, -3, 1.5, -2] 

params = initial_params

p= 'c1'

gradient_descent_boosting1(params, p)
# Out:
# Now descent
# gradient with respect to c1 = 1.1116386829934655
# grad=1.1116386829934655 >0, move backward
# before update, this parameter=2
# after update, this parameter=-3.5581934149673273
# difference = 5.558193414967327
#
#
# Now descent
# gradient with respect to c1 = -21.843846540757994
# grad=-21.843846540757994 <0, move forward
# before update, this parameter=-3.5581934149673273
# after update, this parameter=105.66103928882265
# difference = 109.21923270378997
#
#
# Now descent
# gradient with respect to c1 = -0.02391819949942864
# grad=-0.02391819949942864 <0, move forward
# before update, this parameter=105.66103928882265
# after update, this parameter=105.78063028631979
# difference = 0.11959099749714142
#
#
# Now descent
# gradient with respect to c1 = -0.023859650611024463
# grad=-0.023859650611024463 <0, move forward
# before update, this parameter=105.78063028631979
# after update, this parameter=105.89992853937491
# difference = 0.11929825305512054
#
#
# Now descent
# gradient with respect to c1 = -0.023804930990634077
# grad=-0.023804930990634077 <0, move forward
# before update, this parameter=105.89992853937491
# after update, this parameter=106.01895319432808
# difference = 0.11902465495316505
#
#
# Now descent
# gradient with respect to c1 = -0.023748941534895707
# grad=-0.023748941534895707 <0, move forward
# before update, this parameter=106.01895319432808
# after update, this parameter=106.13769790200256
# difference = 0.11874470767448031
#
#
# Now descent
# gradient with respect to c1 = -0.023687814965756004
# grad=-0.023687814965756004 <0, move forward
# before update, this parameter=106.13769790200256
# after update, this parameter=106.25613697683134
# difference = 0.11843907482878535
#
#
# Now descent
# gradient with respect to c1 = -0.023630793119400195
# grad=-0.023630793119400195 <0, move forward
# before update, this parameter=106.25613697683134
# after update, this parameter=106.37429094242835
# difference = 0.11815396559700275
#
#
# Now descent
# gradient with respect to c1 = -0.02357109152595349
# grad=-0.02357109152595349 <0, move forward
# before update, this parameter=106.37429094242835
# after update, this parameter=106.49214640005812
# difference = 0.11785545762977279
#
#
# Now descent
# gradient with respect to c1 = -0.023516687876590225
# grad=-0.023516687876590225 <0, move forward
# before update, this parameter=106.49214640005812
# after update, this parameter=106.60972983944107
# difference = 0.11758343938295468
#
#
# Now descent
# gradient with respect to c1 = -0.023461891660359058
# grad=-0.023461891660359058 <0, move forward
# before update, this parameter=106.60972983944107
# after update, this parameter=106.72703929774286
# difference = 0.11730945830178996
#
#
# Now descent
# gradient with respect to c1 = -0.02340296058278568
# grad=-0.02340296058278568 <0, move forward
# before update, this parameter=106.72703929774286
# after update, this parameter=106.84405410065679
# difference = 0.1170148029139284
#
#
# Now descent
# gradient with respect to c1 = -0.023354492036498087
# grad=-0.023354492036498087 <0, move forward
# before update, this parameter=106.84405410065679
# after update, this parameter=106.96082656083928
# difference = 0.11677246018248866
#
#
# Now descent
# gradient with respect to c1 = -0.023295153083857656
# grad=-0.023295153083857656 <0, move forward
# before update, this parameter=106.96082656083928
# after update, this parameter=107.07730232625858
# difference = 0.11647576541929539
#
#
# Now descent
# gradient with respect to c1 = -0.023235150023337425
# grad=-0.023235150023337425 <0, move forward
# before update, this parameter=107.07730232625858
# after update, this parameter=107.19347807637526
# difference = 0.1161757501166818
#
#
# Now descent
# gradient with respect to c1 = -0.023187870742402694
# grad=-0.023187870742402694 <0, move forward
# before update, this parameter=107.19347807637526
# after update, this parameter=107.30941743008727
# difference = 0.11593935371200814
#
#
# Now descent
# gradient with respect to c1 = -0.023135190333256617
# grad=-0.023135190333256617 <0, move forward
# before update, this parameter=107.30941743008727
# after update, this parameter=107.42509338175356
# difference = 0.11567595166629019
#
#
# Now descent
# gradient with respect to c1 = -0.023075976052000513
# grad=-0.023075976052000513 <0, move forward
# before update, this parameter=107.42509338175356
# after update, this parameter=107.54047326201356
# difference = 0.1153798802600079
#
#
# Now descent
# gradient with respect to c1 = -0.023024739371990677
# grad=-0.023024739371990677 <0, move forward
# before update, this parameter=107.54047326201356
# after update, this parameter=107.65559695887352
# difference = 0.11512369685995338
#
#
# Now descent
# gradient with respect to c1 = -0.022971681298944446
# grad=-0.022971681298944446 <0, move forward
# before update, this parameter=107.65559695887352
# after update, this parameter=107.77045536536824
# difference = 0.11485840649471868
#
#
# Now descent
# gradient with respect to c1 = -0.022909085501066073
# grad=-0.022909085501066073 <0, move forward
# before update, this parameter=107.77045536536824
# after update, this parameter=107.88500079287357
# difference = 0.11454542750533392
#
#
# Now descent
# gradient with respect to c1 = -0.02287048671179015
# grad=-0.02287048671179015 <0, move forward
# before update, this parameter=107.88500079287357
# after update, this parameter=107.99935322643252
# difference = 0.11435243355894897
#
#
# Now descent
# gradient with respect to c1 = -0.022814727671516266
# grad=-0.022814727671516266 <0, move forward
# before update, this parameter=107.99935322643252
# after update, this parameter=108.1134268647901
# difference = 0.11407363835758133
#
#
# Now descent
# gradient with respect to c1 = -0.022764758109250494
# grad=-0.022764758109250494 <0, move forward
# before update, this parameter=108.1134268647901
# after update, this parameter=108.22725065533635
# difference = 0.11382379054624892
#
#
# Now descent
# gradient with respect to c1 = -0.022731096215533597
# grad=-0.022731096215533597 <0, move forward
# before update, this parameter=108.22725065533635
# after update, this parameter=108.34090613641402
# difference = 0.11365548107767154
#
#
# Now descent
# gradient with respect to c1 = -0.022660763938642248
# grad=-0.022660763938642248 <0, move forward
# before update, this parameter=108.34090613641402
# after update, this parameter=108.45420995610723
# difference = 0.11330381969321479
#
#
# Now descent
# gradient with respect to c1 = -0.02260659768982265
# grad=-0.02260659768982265 <0, move forward
# before update, this parameter=108.45420995610723
# after update, this parameter=108.56724294455634
# difference = 0.11303298844910614
#
#
# Now descent
# gradient with respect to c1 = -0.022556056943789926
# grad=-0.022556056943789926 <0, move forward
# before update, this parameter=108.56724294455634
# after update, this parameter=108.68002322927529
# difference = 0.1127802847189514
#
#
# Now descent
# gradient with respect to c1 = -0.022506980248415687
# grad=-0.022506980248415687 <0, move forward
# before update, this parameter=108.68002322927529
# after update, this parameter=108.79255813051736
# difference = 0.11253490124207133
#
#
# Now descent
# gradient with respect to c1 = -0.022452272941508866
# grad=-0.022452272941508866 <0, move forward
# before update, this parameter=108.79255813051736
# after update, this parameter=108.90481949522491
# difference = 0.11226136470754966
#
#
# Now descent
# gradient with respect to c1 = -0.02240405602815798
# grad=-0.02240405602815798 <0, move forward
# before update, this parameter=108.90481949522491
# after update, this parameter=109.0168397753657
# difference = 0.1120202801407828
#
#
# Now descent
# gradient with respect to c1 = -0.02235206296918868
# grad=-0.02235206296918868 <0, move forward
# before update, this parameter=109.0168397753657
# after update, this parameter=109.12860009021163
# difference = 0.11176031484593807
#
#
# Now descent
# gradient with respect to c1 = -0.022299501063915983
# grad=-0.022299501063915983 <0, move forward
# before update, this parameter=109.12860009021163
# after update, this parameter=109.24009759553121
# difference = 0.11149750531957636
#
#
# Now descent
# gradient with respect to c1 = -0.022254598072146692
# grad=-0.022254598072146692 <0, move forward
# before update, this parameter=109.24009759553121
# after update, this parameter=109.35137058589194
# difference = 0.11127299036073168
#
#
# Now descent
# gradient with respect to c1 = -0.022203971939749323
# grad=-0.022203971939749323 <0, move forward
# before update, this parameter=109.35137058589194
# after update, this parameter=109.46239044559069
# difference = 0.11101985969874306
#
#
# Now descent
# gradient with respect to c1 = -0.022159299680968303
# grad=-0.022159299680968303 <0, move forward
# before update, this parameter=109.46239044559069
# after update, this parameter=109.57318694399552
# difference = 0.11079649840483796
#
#
# Now descent
# gradient with respect to c1 = -0.022105564571273106
# grad=-0.022105564571273106 <0, move forward
# before update, this parameter=109.57318694399552
# after update, this parameter=109.68371476685189
# difference = 0.11052782285636908
#
#
# Now descent
# gradient with respect to c1 = -0.02206101932999971
# grad=-0.02206101932999971 <0, move forward
# before update, this parameter=109.68371476685189
# after update, this parameter=109.79401986350189
# difference = 0.110305096649995
#
#
# Now descent
# gradient with respect to c1 = -0.022011371942021185
# grad=-0.022011371942021185 <0, move forward
# before update, this parameter=109.79401986350189
# after update, this parameter=109.904076723212
# difference = 0.11005685971011303
#
#
# Now descent
# gradient with respect to c1 = -0.02196188345271466
# grad=-0.02196188345271466 <0, move forward
# before update, this parameter=109.904076723212
# after update, this parameter=110.01388614047558
# difference = 0.10980941726357685
#
#
# Now descent
# gradient with respect to c1 = -0.0219019861562586
# grad=-0.0219019861562586 <0, move forward
# before update, this parameter=110.01388614047558
# after update, this parameter=110.12339607125688
# difference = 0.10950993078130011
#
#
# Now descent
# gradient with respect to c1 = -0.021868327976459767
# grad=-0.021868327976459767 <0, move forward
# before update, this parameter=110.12339607125688
# after update, this parameter=110.23273771113918
# difference = 0.10934163988230239
#
#
# Now descent
# gradient with respect to c1 = -0.02182433172226439
# grad=-0.02182433172226439 <0, move forward
# before update, this parameter=110.23273771113918
# after update, this parameter=110.3418593697505
# difference = 0.10912165861131484
#
#
# Now descent
# gradient with respect to c1 = -0.02177558178972916
# grad=-0.02177558178972916 <0, move forward
# before update, this parameter=110.3418593697505
# after update, this parameter=110.45073727869914
# difference = 0.10887790894864224
#
#
# Now descent
# gradient with respect to c1 = -0.021726870936156217
# grad=-0.021726870936156217 <0, move forward
# before update, this parameter=110.45073727869914
# after update, this parameter=110.55937163337993
# difference = 0.10863435468078819
#
#
# Now descent
# gradient with respect to c1 = -0.0216829322641221
# grad=-0.0216829322641221 <0, move forward
# before update, this parameter=110.55937163337993
# after update, this parameter=110.66778629470053
# difference = 0.10841466132060873
#
#
# Now descent
# gradient with respect to c1 = -0.021644049408298116
# grad=-0.021644049408298116 <0, move forward
# before update, this parameter=110.66778629470053
# after update, this parameter=110.77600654174202
# difference = 0.10822024704148703
#
#
# Now descent
# gradient with respect to c1 = -0.02158921651340684
# grad=-0.02158921651340684 <0, move forward
# before update, this parameter=110.77600654174202
# after update, this parameter=110.88395262430906
# difference = 0.10794608256703953
#
#
# Now descent
# gradient with respect to c1 = -0.021542540243002506
# grad=-0.021542540243002506 <0, move forward
# before update, this parameter=110.88395262430906
# after update, this parameter=110.99166532552407
# difference = 0.1077127012150072
#
#
# Now descent
# gradient with respect to c1 = -0.021497783225354894
# grad=-0.021497783225354894 <0, move forward
# before update, this parameter=110.99166532552407
# after update, this parameter=111.09915424165084
# difference = 0.10748891612676914
#
#
# Now descent
# gradient with respect to c1 = -0.021419790673604666
# grad=-0.021419790673604666 <0, move forward
# before update, this parameter=111.09915424165084
# after update, this parameter=111.20625319501886
# difference = 0.10709895336802333
#
#
# Now descent
# gradient with respect to c1 = -0.021406214551378255
# grad=-0.021406214551378255 <0, move forward
# before update, this parameter=111.20625319501886
# after update, this parameter=111.31328426777576
# difference = 0.1070310727568966
#
#
# Now descent
# gradient with respect to c1 = -0.021362608444652764
# grad=-0.021362608444652764 <0, move forward
# before update, this parameter=111.31328426777576
# after update, this parameter=111.42009730999902
# difference = 0.1068130422232656
#
#
# Now descent
# gradient with respect to c1 = -0.021317631613282373
# grad=-0.021317631613282373 <0, move forward
# before update, this parameter=111.42009730999902
# after update, this parameter=111.52668546806544
# difference = 0.10658815806641542
#
#
# Now descent
# gradient with respect to c1 = -0.021272663338622877
# grad=-0.021272663338622877 <0, move forward
# before update, this parameter=111.52668546806544
# after update, this parameter=111.63304878475856
# difference = 0.10636331669311971
#
#
# Now descent
# gradient with respect to c1 = -0.021229809967993063
# grad=-0.021229809967993063 <0, move forward
# before update, this parameter=111.63304878475856
# after update, this parameter=111.73919783459853
# difference = 0.10614904983997064
#
#
# Now descent
# gradient with respect to c1 = -0.0211871656723428
# grad=-0.0211871656723428 <0, move forward
# before update, this parameter=111.73919783459853
# after update, this parameter=111.84513366296024
# difference = 0.10593582836170867
#
#
# Now descent
# gradient with respect to c1 = -0.021134503012110173
# grad=-0.021134503012110173 <0, move forward
# before update, this parameter=111.84513366296024
# after update, this parameter=111.95080617802078
# difference = 0.10567251506054731
#
#
# Now descent
# gradient with respect to c1 = -0.0210949236862934
# grad=-0.0210949236862934 <0, move forward
# before update, this parameter=111.95080617802078
# after update, this parameter=112.05628079645226
# difference = 0.10547461843147232
#
#
# Now descent
# gradient with respect to c1 = -0.021053423538308635
# grad=-0.021053423538308635 <0, move forward
# before update, this parameter=112.05628079645226
# after update, this parameter=112.1615479141438
# difference = 0.10526711769153962
#
#
# Now descent
# gradient with respect to c1 = -0.0210075883362304
# grad=-0.0210075883362304 <0, move forward
# before update, this parameter=112.1615479141438
# after update, this parameter=112.26658585582494
# difference = 0.10503794168114666
#
#
# Now descent
# gradient with respect to c1 = -0.020967329425358727
# grad=-0.020967329425358727 <0, move forward
# before update, this parameter=112.26658585582494
# after update, this parameter=112.37142250295173
# difference = 0.10483664712678831
#
#
# Now descent
# gradient with respect to c1 = -0.02092447570745115
# grad=-0.02092447570745115 <0, move forward
# before update, this parameter=112.37142250295173
# after update, this parameter=112.47604488148899
# difference = 0.10462237853725753
#
#
# Now descent
# gradient with respect to c1 = -0.020881546989315325
# grad=-0.020881546989315325 <0, move forward
# before update, this parameter=112.47604488148899
# after update, this parameter=112.58045261643557
# difference = 0.10440773494657662
#
#
# Now descent
# gradient with respect to c1 = -0.020837260883199704
# grad=-0.020837260883199704 <0, move forward
# before update, this parameter=112.58045261643557
# after update, this parameter=112.68463892085157
# difference = 0.10418630441600385
#
#
# Now descent
# gradient with respect to c1 = -0.020794125639822525
# grad=-0.020794125639822525 <0, move forward
# before update, this parameter=112.68463892085157
# after update, this parameter=112.78860954905068
# difference = 0.1039706281991073
#
#
# Now descent
# gradient with respect to c1 = -0.020755712606845833
# grad=-0.020755712606845833 <0, move forward
# before update, this parameter=112.78860954905068
# after update, this parameter=112.8923881120849
# difference = 0.10377856303422561
#
#
# Now descent
# gradient with respect to c1 = -0.02071432202677137
# grad=-0.02071432202677137 <0, move forward
# before update, this parameter=112.8923881120849
# after update, this parameter=112.99595972221876
# difference = 0.10357161013385507
#
#
# Now descent
# gradient with respect to c1 = -0.02067296765062565
# grad=-0.02067296765062565 <0, move forward
# before update, this parameter=112.99595972221876
# after update, this parameter=113.09932456047189
# difference = 0.10336483825312826
#
#
# Now descent
# gradient with respect to c1 = -0.02062680790060334
# grad=-0.02062680790060334 <0, move forward
# before update, this parameter=113.09932456047189
# after update, this parameter=113.2024585999749
# difference = 0.10313403950301847
#
#
# Now descent
# gradient with respect to c1 = -0.02059086341321681
# grad=-0.02059086341321681 <0, move forward
# before update, this parameter=113.2024585999749
# after update, this parameter=113.30541291704098
# difference = 0.10295431706607872
#
#
# Now descent
# gradient with respect to c1 = -0.02054512203208958
# grad=-0.02054512203208958 <0, move forward
# before update, this parameter=113.30541291704098
# after update, this parameter=113.40813852720143
# difference = 0.1027256101604479
#
#
# Now descent
# gradient with respect to c1 = -0.020507917245948803
# grad=-0.020507917245948803 <0, move forward
# before update, this parameter=113.40813852720143
# after update, this parameter=113.51067811343117
# difference = 0.10253958622973869
#
#
# Now descent
# gradient with respect to c1 = -0.020466493615867165
# grad=-0.020466493615867165 <0, move forward
# before update, this parameter=113.51067811343117
# after update, this parameter=113.61301058151051
# difference = 0.10233246807933938
#
#
# Now descent
# gradient with respect to c1 = -0.020433152713605907
# grad=-0.020433152713605907 <0, move forward
# before update, this parameter=113.61301058151051
# after update, this parameter=113.71517634507853
# difference = 0.1021657635680242
#
#
# Now descent
# gradient with respect to c1 = -0.020381720414519577
# grad=-0.020381720414519577 <0, move forward
# before update, this parameter=113.71517634507853
# after update, this parameter=113.81708494715113
# difference = 0.10190860207259789
#
#
# Now descent
# gradient with respect to c1 = -0.020344668538507804
# grad=-0.020344668538507804 <0, move forward
# before update, this parameter=113.81708494715113
# after update, this parameter=113.91880828984367
# difference = 0.10172334269253724
#
#
# Now descent
# gradient with respect to c1 = -0.020311661844685247
# grad=-0.020311661844685247 <0, move forward
# before update, this parameter=113.91880828984367
# after update, this parameter=114.02036659906709
# difference = 0.1015583092234209
#
#
# Now descent
# gradient with respect to c1 = -0.02026612469685496
# grad=-0.02026612469685496 <0, move forward
# before update, this parameter=114.02036659906709
# after update, this parameter=114.12169722255136
# difference = 0.10133062348427302
#
#
# Now descent
# gradient with respect to c1 = -0.020225229514725385
# grad=-0.020225229514725385 <0, move forward
# before update, this parameter=114.12169722255136
# after update, this parameter=114.22282337012498
# difference = 0.10112614757362337
#
#
# Now descent
# gradient with respect to c1 = -0.020183117914962523
# grad=-0.020183117914962523 <0, move forward
# before update, this parameter=114.22282337012498
# after update, this parameter=114.3237389596998
# difference = 0.10091558957481084
#
#
# Now descent
# gradient with respect to c1 = -0.020144585054282516
# grad=-0.020144585054282516 <0, move forward
# before update, this parameter=114.3237389596998
# after update, this parameter=114.42446188497121
# difference = 0.10072292527141258
#
#
# Now descent
# gradient with respect to c1 = -0.0201040278193787
# grad=-0.0201040278193787 <0, move forward
# before update, this parameter=114.42446188497121
# after update, this parameter=114.5249820240681
# difference = 0.1005201390968864
#
#
# Now descent
# gradient with respect to c1 = -0.020068709509102334
# grad=-0.020068709509102334 <0, move forward
# before update, this parameter=114.5249820240681
# after update, this parameter=114.6253255716136
# difference = 0.10034354754550634
#
#
# Now descent
# gradient with respect to c1 = -0.020030676212368093
# grad=-0.020030676212368093 <0, move forward
# before update, this parameter=114.6253255716136
# after update, this parameter=114.72547895267545
# difference = 0.10015338106184402
#
#
# Now descent
# gradient with respect to c1 = -0.01999135577790412
# grad=-0.01999135577790412 <0, move forward
# before update, this parameter=114.72547895267545
# after update, this parameter=114.82543573156497
# difference = 0.09995677888952059
#
#
# Now descent
# gradient with respect to c1 = -0.019952499159092696
# grad=-0.019952499159092696 <0, move forward
# before update, this parameter=114.82543573156497
# after update, this parameter=114.92519822736043
# difference = 0.09976249579545993
#
#
# Now descent
# gradient with respect to c1 = -0.01991104901843954
# grad=-0.01991104901843954 <0, move forward
# before update, this parameter=114.92519822736043
# after update, this parameter=115.02475347245263
# difference = 0.09955524509220481
#
#
# Now descent
# gradient with respect to c1 = -0.019875464618568373
# grad=-0.019875464618568373 <0, move forward
# before update, this parameter=115.02475347245263
# after update, this parameter=115.12413079554547
# difference = 0.09937732309283831
#
#
# Now descent
# gradient with respect to c1 = -0.019826777267528684
# grad=-0.019826777267528684 <0, move forward
# before update, this parameter=115.12413079554547
# after update, this parameter=115.22326468188311
# difference = 0.09913388633763986
#
#
# Now descent
# gradient with respect to c1 = -0.019800665217006852
# grad=-0.019800665217006852 <0, move forward
# before update, this parameter=115.22326468188311
# after update, this parameter=115.32226800796815
# difference = 0.09900332608503959
#
#
# Now descent
# gradient with respect to c1 = -0.01976131522352098
# grad=-0.01976131522352098 <0, move forward
# before update, this parameter=115.32226800796815
# after update, this parameter=115.42107458408576
# difference = 0.09880657611761023
#
#
# Now descent
# gradient with respect to c1 = -0.019725518709767798
# grad=-0.019725518709767798 <0, move forward
# before update, this parameter=115.42107458408576
# after update, this parameter=115.5197021776346
# difference = 0.09862759354884076
#
#
# Now descent
# gradient with respect to c1 = -0.019688115624472147
# grad=-0.019688115624472147 <0, move forward
# before update, this parameter=115.5197021776346
# after update, this parameter=115.61814275575696
# difference = 0.09844057812236429
#
#
# Now descent
# gradient with respect to c1 = -0.019647095215624688
# grad=-0.019647095215624688 <0, move forward
# before update, this parameter=115.61814275575696
# after update, this parameter=115.71637823183508
# difference = 0.09823547607811633
#
#
# Now descent
# gradient with respect to c1 = -0.019620183713708883
# grad=-0.019620183713708883 <0, move forward
# before update, this parameter=115.71637823183508
# after update, this parameter=115.81447915040363
# difference = 0.09810091856854797
#
#
# Now descent
# gradient with respect to c1 = -0.01957517194517422
# grad=-0.01957517194517422 <0, move forward
# before update, this parameter=115.81447915040363
# after update, this parameter=115.9123550101295
# difference = 0.09787585972587465
#
#
# Now descent
# gradient with respect to c1 = -0.019573616397261517
# grad=-0.019573616397261517 <0, move forward
# before update, this parameter=115.9123550101295
# after update, this parameter=116.01022309211581
# difference = 0.09786808198630581
#
#
# Now descent
# gradient with respect to c1 = -0.019506973062854982
# grad=-0.019506973062854982 <0, move forward
# before update, this parameter=116.01022309211581
# after update, this parameter=116.10775795743008
# difference = 0.09753486531427313
#
#
# Now descent
# gradient with respect to c1 = -0.019459556982681647
# grad=-0.019459556982681647 <0, move forward
# before update, this parameter=116.10775795743008
# after update, this parameter=116.20505574234349
# difference = 0.09729778491340824
#
#
# Now descent
# gradient with respect to c1 = -0.019428103500640503
# grad=-0.019428103500640503 <0, move forward
# before update, this parameter=116.20505574234349
# after update, this parameter=116.3021962598467
# difference = 0.09714051750320607
#
#
# Now descent
# gradient with respect to c1 = -0.01939515479842946
# grad=-0.01939515479842946 <0, move forward
# before update, this parameter=116.3021962598467
# after update, this parameter=116.39917203383884
# difference = 0.09697577399214197
#
#
# Now descent
# gradient with respect to c1 = -0.019360681630331555
# grad=-0.019360681630331555 <0, move forward
# before update, this parameter=116.39917203383884
# after update, this parameter=116.4959754419905
# difference = 0.09680340815165778
#
#
# Now descent
# gradient with respect to c1 = -0.019323155813433246
# grad=-0.019323155813433246 <0, move forward
# before update, this parameter=116.4959754419905
# after update, this parameter=116.59259122105766
# difference = 0.09661577906716445
#
#
# Now descent
# gradient with respect to c1 = -0.019287249177768473
# grad=-0.019287249177768473 <0, move forward
# before update, this parameter=116.59259122105766
# after update, this parameter=116.6890274669465
# difference = 0.09643624588883881
#
#
# Now descent
# gradient with respect to c1 = -0.019245253630062464
# grad=-0.019245253630062464 <0, move forward
# before update, this parameter=116.6890274669465
# after update, this parameter=116.78525373509682
# difference = 0.09622626815031765
#
#
# Now descent
# gradient with respect to c1 = -0.01921688363104579
# grad=-0.01921688363104579 <0, move forward
# before update, this parameter=116.78525373509682
# after update, this parameter=116.88133815325205
# difference = 0.09608441815522895
#
#
# Now descent
# gradient with respect to c1 = -0.01918372960796333
# grad=-0.01918372960796333 <0, move forward
# before update, this parameter=116.88133815325205
# after update, this parameter=116.97725680129186
# difference = 0.09591864803981309
#
#
# Now descent
# gradient with respect to c1 = -0.019144784080493693
# grad=-0.019144784080493693 <0, move forward
# before update, this parameter=116.97725680129186
# after update, this parameter=117.07298072169432
# difference = 0.09572392040246314
#
#
# Now descent
# gradient with respect to c1 = -0.019107979443155898
# grad=-0.019107979443155898 <0, move forward
# before update, this parameter=117.07298072169432
# after update, this parameter=117.1685206189101
# difference = 0.09553989721577238
#
#
# Now descent
# gradient with respect to c1 = -0.019080039702190632
# grad=-0.019080039702190632 <0, move forward
# before update, this parameter=117.1685206189101
# after update, this parameter=117.26392081742105
# difference = 0.09540019851095849
#
#
# Now descent
# gradient with respect to c1 = -0.01904524656626272
# grad=-0.01904524656626272 <0, move forward
# before update, this parameter=117.26392081742105
# after update, this parameter=117.35914705025236
# difference = 0.09522623283130827
#
#
# Now descent
# gradient with respect to c1 = -0.019013393359301745
# grad=-0.019013393359301745 <0, move forward
# before update, this parameter=117.35914705025236
# after update, this parameter=117.45421401704887
# difference = 0.09506696679650872
#
#
# Now descent
# gradient with respect to c1 = -0.018973440760738924
# grad=-0.018973440760738924 <0, move forward
# before update, this parameter=117.45421401704887
# after update, this parameter=117.54908122085257
# difference = 0.09486720380370173
#
#
# Now descent
# gradient with respect to c1 = -0.01893998489177484
# grad=-0.01893998489177484 <0, move forward
# before update, this parameter=117.54908122085257
# after update, this parameter=117.64378114531145
# difference = 0.09469992445887954
#
#
# Now descent
# gradient with respect to c1 = -0.01890870299070535
# grad=-0.01890870299070535 <0, move forward
# before update, this parameter=117.64378114531145
# after update, this parameter=117.73832466026498
# difference = 0.09454351495352853
#
#
# Now descent
# gradient with respect to c1 = -0.018895424628961877
# grad=-0.018895424628961877 <0, move forward
# before update, this parameter=117.73832466026498
# after update, this parameter=117.83280178340979
# difference = 0.09447712314481294
#
#
# Now descent
# gradient with respect to c1 = -0.018834941783563153
# grad=-0.018834941783563153 <0, move forward
# before update, this parameter=117.83280178340979
# after update, this parameter=117.92697649232761
# difference = 0.09417470891781932
#
#
# Now descent
# gradient with respect to c1 = -0.01880448377056254
# grad=-0.01880448377056254 <0, move forward
# before update, this parameter=117.92697649232761
# after update, this parameter=118.02099891118043
# difference = 0.09402241885281626
#
#
# Now descent
# gradient with respect to c1 = -0.018776421282007405
# grad=-0.018776421282007405 <0, move forward
# before update, this parameter=118.02099891118043
# after update, this parameter=118.11488101759046
# difference = 0.09388210641003525
#
#
# Now descent
# gradient with respect to c1 = -0.01873781928374285
# grad=-0.01873781928374285 <0, move forward
# before update, this parameter=118.11488101759046
# after update, this parameter=118.20857011400918
# difference = 0.09368909641871426
#
#
# Now descent
# gradient with respect to c1 = -0.01870608378418126
# grad=-0.01870608378418126 <0, move forward
# before update, this parameter=118.20857011400918
# after update, this parameter=118.30210053293008
# difference = 0.0935304189209063
#
#
# Now descent
# gradient with respect to c1 = -0.018669230254841906
# grad=-0.018669230254841906 <0, move forward
# before update, this parameter=118.30210053293008
# after update, this parameter=118.39544668420429
# difference = 0.0933461512742042
#
#
# Now descent
# gradient with respect to c1 = -0.018641184411638534
# grad=-0.018641184411638534 <0, move forward
# before update, this parameter=118.39544668420429
# after update, this parameter=118.48865260626248
# difference = 0.09320592205818912
#
#
# Now descent
# gradient with respect to c1 = -0.018609861656138094
# grad=-0.018609861656138094 <0, move forward
# before update, this parameter=118.48865260626248
# after update, this parameter=118.58170191454317
# difference = 0.09304930828069757
#
#
# Now descent
# gradient with respect to c1 = -0.01857483585276931
# grad=-0.01857483585276931 <0, move forward
# before update, this parameter=118.58170191454317
# after update, this parameter=118.67457609380702
# difference = 0.09287417926384478
#
#
# Now descent
# gradient with respect to c1 = -0.018526176552402518
# grad=-0.018526176552402518 <0, move forward
# before update, this parameter=118.67457609380702
# after update, this parameter=118.76720697656903
# difference = 0.09263088276200904
#
#
# Now descent
# gradient with respect to c1 = -0.018509176827885554
# grad=-0.018509176827885554 <0, move forward
# before update, this parameter=118.76720697656903
# after update, this parameter=118.85975286070845
# difference = 0.092545884139426
#
#
# Now descent
# gradient with respect to c1 = -0.018475556468500187
# grad=-0.018475556468500187 <0, move forward
# before update, this parameter=118.85975286070845
# after update, this parameter=118.95213064305095
# difference = 0.0923777823424956
#
#
# Now descent
# gradient with respect to c1 = -0.01844484041391148
# grad=-0.01844484041391148 <0, move forward
# before update, this parameter=118.95213064305095
# after update, this parameter=119.04435484512051
# difference = 0.09222420206955917
#
#
# Now descent
# gradient with respect to c1 = -0.018421823632097656
# grad=-0.018421823632097656 <0, move forward
# before update, this parameter=119.04435484512051
# after update, this parameter=119.136463963281
# difference = 0.09210911816049361
#
#
# Now descent
# gradient with respect to c1 = -0.01837562602768905
# grad=-0.01837562602768905 <0, move forward
# before update, this parameter=119.136463963281
# after update, this parameter=119.22834209341944
# difference = 0.09187813013843993
#
#
# Now descent
# gradient with respect to c1 = -0.01832919656163945
# grad=-0.01832919656163945 <0, move forward
# before update, this parameter=119.22834209341944
# after update, this parameter=119.31998807622765
# difference = 0.09164598280820258
#
#
# Now descent
# gradient with respect to c1 = -0.0183197199510321
# grad=-0.0183197199510321 <0, move forward
# before update, this parameter=119.31998807622765
# after update, this parameter=119.4115866759828
# difference = 0.09159859975515872
#
#
# Now descent
# gradient with respect to c1 = -0.01828662485015009
# grad=-0.01828662485015009 <0, move forward
# before update, this parameter=119.4115866759828
# after update, this parameter=119.50301980023356
# difference = 0.09143312425075578
#
#
# Now descent
# gradient with respect to c1 = -0.018252010838715194
# grad=-0.018252010838715194 <0, move forward
# before update, this parameter=119.50301980023356
# after update, this parameter=119.59427985442713
# difference = 0.09126005419356886
#
#
# Now descent
# gradient with respect to c1 = -0.018222828143565906
# grad=-0.018222828143565906 <0, move forward
# before update, this parameter=119.59427985442713
# after update, this parameter=119.68539399514496
# difference = 0.09111414071783486
#
#
# Now descent
# gradient with respect to c1 = -0.018200292584591438
# grad=-0.018200292584591438 <0, move forward
# before update, this parameter=119.68539399514496
# after update, this parameter=119.77639545806792
# difference = 0.09100146292296074
#
#
# Now descent
# gradient with respect to c1 = -0.01814595060278812
# grad=-0.01814595060278812 <0, move forward
# before update, this parameter=119.77639545806792
# after update, this parameter=119.86712521108187
# difference = 0.09072975301394592
#
#
# Now descent
# gradient with respect to c1 = -0.018134360183719167
# grad=-0.018134360183719167 <0, move forward
# before update, this parameter=119.86712521108187
# after update, this parameter=119.95779701200047
# difference = 0.09067180091859939
#
#
# Now descent
# gradient with respect to c1 = -0.018097332254329856
# grad=-0.018097332254329856 <0, move forward
# before update, this parameter=119.95779701200047
# after update, this parameter=120.04828367327212
# difference = 0.09048666127165461
#
#
# Now descent
# gradient with respect to c1 = -0.01806864094300309
# grad=-0.01806864094300309 <0, move forward
# before update, this parameter=120.04828367327212
# after update, this parameter=120.13862687798714
# difference = 0.0903432047150119
#
#
# Now descent
# gradient with respect to c1 = -0.018044683576468046
# grad=-0.018044683576468046 <0, move forward
# before update, this parameter=120.13862687798714
# after update, this parameter=120.22885029586948
# difference = 0.090223417882342
#
#
# Now descent
# gradient with respect to c1 = -0.018010222261111153
# grad=-0.018010222261111153 <0, move forward
# before update, this parameter=120.22885029586948
# after update, this parameter=120.31890140717503
# difference = 0.09005111130555576
#
#
# Now descent
# gradient with respect to c1 = -0.01797917608215016
# grad=-0.01797917608215016 <0, move forward
# before update, this parameter=120.31890140717503
# after update, this parameter=120.40879728758578
# difference = 0.0898958804107508
#
#
# Now descent
# gradient with respect to c1 = -0.017950394376908818
# grad=-0.017950394376908818 <0, move forward
# before update, this parameter=120.40879728758578
# after update, this parameter=120.49854925947032
# difference = 0.08975197188453876
#
#
# Now descent
# gradient with respect to c1 = -0.017919173584068915
# grad=-0.017919173584068915 <0, move forward
# before update, this parameter=120.49854925947032
# after update, this parameter=120.58814512739067
# difference = 0.08959586792035168
#
#
# Now descent
# gradient with respect to c1 = -0.01788833582705429
# grad=-0.01788833582705429 <0, move forward
# before update, this parameter=120.58814512739067
# after update, this parameter=120.67758680652595
# difference = 0.08944167913527679
#
#
# Now descent
# gradient with respect to c1 = -0.017860432349969813
# grad=-0.017860432349969813 <0, move forward
# before update, this parameter=120.67758680652595
# after update, this parameter=120.7668889682758
# difference = 0.08930216174984196
#
#
# Now descent
# gradient with respect to c1 = -0.0178329210811512
# grad=-0.0178329210811512 <0, move forward
# before update, this parameter=120.7668889682758
# after update, this parameter=120.85605357368155
# difference = 0.08916460540575599
#
#
# Now descent
# gradient with respect to c1 = -0.01780122515504523
# grad=-0.01780122515504523 <0, move forward
# before update, this parameter=120.85605357368155
# after update, this parameter=120.94505969945678
# difference = 0.08900612577522793
#
#
# Now descent
# gradient with respect to c1 = -0.017771200659044695
# grad=-0.017771200659044695 <0, move forward
# before update, this parameter=120.94505969945678
# after update, this parameter=121.033915702752
# difference = 0.08885600329521992
#
#
# Now descent
# gradient with respect to c1 = -0.017740273923427807
# grad=-0.017740273923427807 <0, move forward
# before update, this parameter=121.033915702752
# after update, this parameter=121.12261707236914
# difference = 0.08870136961714081
#
#
# Now descent
# gradient with respect to c1 = -0.01771072193346157
# grad=-0.01771072193346157 <0, move forward
# before update, this parameter=121.12261707236914
# after update, this parameter=121.21117068203645
# difference = 0.08855360966731496
#
#
# Now descent
# gradient with respect to c1 = -0.017689978826895825
# grad=-0.017689978826895825 <0, move forward
# before update, this parameter=121.21117068203645
# after update, this parameter=121.29962057617094
# difference = 0.08844989413448445
#
#
# Now descent
# gradient with respect to c1 = -0.017654765965158248
# grad=-0.017654765965158248 <0, move forward
# before update, this parameter=121.29962057617094
# after update, this parameter=121.38789440599673
# difference = 0.08827382982579479
#
#
# Now descent
# gradient with respect to c1 = -0.01762394365867337
# grad=-0.01762394365867337 <0, move forward
# before update, this parameter=121.38789440599673
# after update, this parameter=121.4760141242901
# difference = 0.0881197182933704
#
#
# Now descent
# gradient with respect to c1 = -0.017603624339335155
# grad=-0.017603624339335155 <0, move forward
# before update, this parameter=121.4760141242901
# after update, this parameter=121.56403224598678
# difference = 0.08801812169667755
#
#
# Now descent
# gradient with respect to c1 = -0.017569571882258828
# grad=-0.017569571882258828 <0, move forward
# before update, this parameter=121.56403224598678
# after update, this parameter=121.65188010539808
# difference = 0.08784785941129769
#
#
# Now descent
# gradient with respect to c1 = -0.017537968973302398
# grad=-0.017537968973302398 <0, move forward
# before update, this parameter=121.65188010539808
# after update, this parameter=121.7395699502646
# difference = 0.08768984486651732
#
#
# Now descent
# gradient with respect to c1 = -0.01750965326485776
# grad=-0.01750965326485776 <0, move forward
# before update, this parameter=121.7395699502646
# after update, this parameter=121.82711821658889
# difference = 0.08754826632429058
#
#
# Now descent
# gradient with respect to c1 = -0.017484943813927956
# grad=-0.017484943813927956 <0, move forward
# before update, this parameter=121.82711821658889
# after update, this parameter=121.91454293565853
# difference = 0.08742471906964511
#
#
# Now descent
# gradient with respect to c1 = -0.01745515748807769
# grad=-0.01745515748807769 <0, move forward
# before update, this parameter=121.91454293565853
# after update, this parameter=122.00181872309892
# difference = 0.08727578744039022
#
#
# Now descent
# gradient with respect to c1 = -0.017429355233966604
# grad=-0.017429355233966604 <0, move forward
# before update, this parameter=122.00181872309892
# after update, this parameter=122.08896549926875
# difference = 0.08714677616983124
#
#
# Now descent
# gradient with respect to c1 = -0.01739817233104013
# grad=-0.01739817233104013 <0, move forward
# before update, this parameter=122.08896549926875
# after update, this parameter=122.17595636092395
# difference = 0.08699086165519532
#
#
# Now descent
# gradient with respect to c1 = -0.017372767584733495
# grad=-0.017372767584733495 <0, move forward
# before update, this parameter=122.17595636092395
# after update, this parameter=122.26282019884762
# difference = 0.0868638379236728
#
#
# Now descent
# gradient with respect to c1 = -0.017345487103970214
# grad=-0.017345487103970214 <0, move forward
# before update, this parameter=122.26282019884762
# after update, this parameter=122.34954763436747
# difference = 0.08672743551984752
#
#
# Now descent
# gradient with respect to c1 = -0.017315620872926374
# grad=-0.017315620872926374 <0, move forward
# before update, this parameter=122.34954763436747
# after update, this parameter=122.4361257387321
# difference = 0.08657810436463365
#
#
# Now descent
# gradient with respect to c1 = -0.017289029429878866
# grad=-0.017289029429878866 <0, move forward
# before update, this parameter=122.4361257387321
# after update, this parameter=122.52257088588149
# difference = 0.08644514714939078
#
#
# Now descent
# gradient with respect to c1 = -0.017262145486363067
# grad=-0.017262145486363067 <0, move forward
# before update, this parameter=122.52257088588149
# after update, this parameter=122.60888161331332
# difference = 0.08631072743182244
#
#
# Now descent
# gradient with respect to c1 = -0.017232504946340654
# grad=-0.017232504946340654 <0, move forward
# before update, this parameter=122.60888161331332
# after update, this parameter=122.69504413804502
# difference = 0.08616252473170505
#
#
# Now descent
# gradient with respect to c1 = -0.01720353995215973
# grad=-0.01720353995215973 <0, move forward
# before update, this parameter=122.69504413804502
# after update, this parameter=122.78106183780582
# difference = 0.0860176997608022
#
#
# Now descent
# gradient with respect to c1 = -0.017177530037271183
# grad=-0.017177530037271183 <0, move forward
# before update, this parameter=122.78106183780582
# after update, this parameter=122.86694948799217
# difference = 0.08588765018635058
#
#
# Now descent
# gradient with respect to c1 = -0.017148388057774966
# grad=-0.017148388057774966 <0, move forward
# before update, this parameter=122.86694948799217
# after update, this parameter=122.95269142828104
# difference = 0.0857419402888695
#
#
# Now descent
# gradient with respect to c1 = -0.017128871082849884
# grad=-0.017128871082849884 <0, move forward
# before update, this parameter=122.95269142828104
# after update, this parameter=123.03833578369529
# difference = 0.08564435541424587
#
#
# Now descent
# gradient with respect to c1 = -0.017099224615346742
# grad=-0.017099224615346742 <0, move forward
# before update, this parameter=123.03833578369529
# after update, this parameter=123.12383190677203
# difference = 0.08549612307673726
#
#
# Now descent
# gradient with respect to c1 = -0.017068960637356412
# grad=-0.017068960637356412 <0, move forward
# before update, this parameter=123.12383190677203
# after update, this parameter=123.20917670995881
# difference = 0.08534480318678561
#
#
# Now descent
# gradient with respect to c1 = -0.017044123529208477
# grad=-0.017044123529208477 <0, move forward
# before update, this parameter=123.20917670995881
# after update, this parameter=123.29439732760486
# difference = 0.08522061764604416
#
#
# Now descent
# gradient with respect to c1 = -0.01701833829526045
# grad=-0.01701833829526045 <0, move forward
# before update, this parameter=123.29439732760486
# after update, this parameter=123.37948901908116
# difference = 0.08509169147630757
#
#
# Now descent
# gradient with respect to c1 = -0.01699528272047779
# grad=-0.01699528272047779 <0, move forward
# before update, this parameter=123.37948901908116
# after update, this parameter=123.46446543268355
# difference = 0.08497641360239072
#
#
# Now descent
# gradient with respect to c1 = -0.016965599479057403
# grad=-0.016965599479057403 <0, move forward
# before update, this parameter=123.46446543268355
# after update, this parameter=123.54929343007885
# difference = 0.08482799739529412
#
#
# Now descent
# gradient with respect to c1 = -0.016936055662553073
# grad=-0.016936055662553073 <0, move forward
# before update, this parameter=123.54929343007885
# after update, this parameter=123.63397370839161
# difference = 0.08468027831276004
#
#
# Now descent
# gradient with respect to c1 = -0.01691181728080693
# grad=-0.01691181728080693 <0, move forward
# before update, this parameter=123.63397370839161
# after update, this parameter=123.71853279479564
# difference = 0.08455908640402754
#
#
# Now descent
# gradient with respect to c1 = -0.0168845732155809
# grad=-0.0168845732155809 <0, move forward
# before update, this parameter=123.71853279479564
# after update, this parameter=123.80295566087354
# difference = 0.08442286607790095
#
#
# Now descent
# gradient with respect to c1 = -0.016857048943608177
# grad=-0.016857048943608177 <0, move forward
# before update, this parameter=123.80295566087354
# after update, this parameter=123.88724090559158
# difference = 0.08428524471804621
#
#
# Now descent
# gradient with respect to c1 = -0.016837340795605726
# grad=-0.016837340795605726 <0, move forward
# before update, this parameter=123.88724090559158
# after update, this parameter=123.97142760956962
# difference = 0.08418670397803396
#
#
# Now descent
# gradient with respect to c1 = -0.016808276859237026
# grad=-0.016808276859237026 <0, move forward
# before update, this parameter=123.97142760956962
# after update, this parameter=124.0554689938658
# difference = 0.08404138429618513
#
#
# Now descent
# gradient with respect to c1 = -0.01678434638385795
# grad=-0.01678434638385795 <0, move forward
# before update, this parameter=124.0554689938658
# after update, this parameter=124.13939072578509
# difference = 0.08392173191928975
#
#
# Now descent
# gradient with respect to c1 = -0.01675550889523869
# grad=-0.01675550889523869 <0, move forward
# before update, this parameter=124.13939072578509
# after update, this parameter=124.22316827026128
# difference = 0.08377754447619168
#
#
# Now descent
# gradient with respect to c1 = -0.016733666009516313
# grad=-0.016733666009516313 <0, move forward
# before update, this parameter=124.22316827026128
# after update, this parameter=124.30683660030887
# difference = 0.08366833004758689
#
#
# Now descent
# gradient with respect to c1 = -0.016705399257688214
# grad=-0.016705399257688214 <0, move forward
# before update, this parameter=124.30683660030887
# after update, this parameter=124.39036359659731
# difference = 0.08352699628844107
#
#
# Now descent
# gradient with respect to c1 = -0.016691908184984783
# grad=-0.016691908184984783 <0, move forward
# before update, this parameter=124.39036359659731
# after update, this parameter=124.47382313752223
# difference = 0.08345954092492036
#
#
# Now descent
# gradient with respect to c1 = -0.016655257616182695
# grad=-0.016655257616182695 <0, move forward
# before update, this parameter=124.47382313752223
# after update, this parameter=124.55709942560314
# difference = 0.08327628808090992
#
#
# Now descent
# gradient with respect to c1 = -0.01662968669058351
# grad=-0.01662968669058351 <0, move forward
# before update, this parameter=124.55709942560314
# after update, this parameter=124.64024785905606
# difference = 0.08314843345291933
#
#
# Now descent
# gradient with respect to c1 = -0.016609062304162592
# grad=-0.016609062304162592 <0, move forward
# before update, this parameter=124.64024785905606
# after update, this parameter=124.72329317057688
# difference = 0.08304531152082006
#
#
# Now descent
# gradient with respect to c1 = -0.01658074437882462
# grad=-0.01658074437882462 <0, move forward
# before update, this parameter=124.72329317057688
# after update, this parameter=124.80619689247101
# difference = 0.08290372189412665
#
#
# Now descent
# gradient with respect to c1 = -0.016552659841684303
# grad=-0.016552659841684303 <0, move forward
# before update, this parameter=124.80619689247101
# after update, this parameter=124.88896019167943
# difference = 0.08276329920842329
#
#
# Now descent
# gradient with respect to c1 = -0.016530701187233987
# grad=-0.016530701187233987 <0, move forward
# before update, this parameter=124.88896019167943
# after update, this parameter=124.9716136976156
# difference = 0.0826535059361646
#
#
# Now descent
# gradient with respect to c1 = -0.016504929711391725
# grad=-0.016504929711391725 <0, move forward
# before update, this parameter=124.9716136976156
# after update, this parameter=125.05413834617255
# difference = 0.08252464855695507
#
#
# Now descent
# gradient with respect to c1 = -0.016481357809183805
# grad=-0.016481357809183805 <0, move forward
# before update, this parameter=125.05413834617255
# after update, this parameter=125.13654513521847
# difference = 0.08240678904591903
#
#
# Now descent
# gradient with respect to c1 = -0.01645482785073149
# grad=-0.01645482785073149 <0, move forward
# before update, this parameter=125.13654513521847
# after update, this parameter=125.21881927447212
# difference = 0.08227413925365568
#
#
# Now descent
# ...
# after update, this parameter=145.154481829181
# difference = 0.05844645803333037
#
#
# Now descent
# gradient with respect to c1 = -0.011676470603960709
# grad=-0.011676470603960709 <0, move forward
# before update, this parameter=145.154481829181
# after update, this parameter=145.2128641822008
# difference = 0.058382353019794664
#
#
# Now descent
# gradient with respect to c1 = -0.011664156604140885
# grad=-0.011664156604140885 <0, move forward
# before update, this parameter=145.2128641822008
# after update, this parameter=145.2711849652215
# difference = 0.058320783020690214
#
#
# Now descent
# gradient with respect to c1 = -0.011650646793981423
# grad=-0.011650646793981423 <0, move forward
# before update, this parameter=145.2711849652215
# after update, this parameter=145.3294381991914
# difference = 0.058253233969907114
#
#
# Now descent
# gradient with respect to c1 = -0.011642978168913132
# grad=-0.011642978168913132 <0, move forward
# before update, this parameter=145.3294381991914
# after update, this parameter=145.38765309003597
# difference = 0.058214890844567435
#
#
# Now descent
# gradient with respect to c1 = -0.011633875005134797
# grad=-0.011633875005134797 <0, move forward
# before update, this parameter=145.38765309003597
# after update, this parameter=145.44582246506164
# difference = 0.05816937502567043
#
#
# Now descent
# gradient with respect to c1 = -0.011616855221330269
# grad=-0.011616855221330269 <0, move forward
# before update, this parameter=145.44582246506164
# after update, this parameter=145.5039067411683
# difference = 0.0580842761066549
#
#
# Now descent
# gradient with respect to c1 = -0.011614723784303393
# grad=-0.011614723784303393 <0, move forward
# before update, this parameter=145.5039067411683
# after update, this parameter=145.56198036008982
# difference = 0.05807361892152585
#
#
# Now descent
# gradient with respect to c1 = -0.011597182264955208
# grad=-0.011597182264955208 <0, move forward
# before update, this parameter=145.56198036008982
# after update, this parameter=145.6199662714146
# difference = 0.05798591132477782
#
#
# Now descent
# gradient with respect to c1 = -0.01158840471293665
# grad=-0.01158840471293665 <0, move forward
# before update, this parameter=145.6199662714146
# after update, this parameter=145.6779082949793
# difference = 0.057942023564692136
#
#
# Now descent
# gradient with respect to c1 = -0.01157724338463062
# grad=-0.01157724338463062 <0, move forward
# before update, this parameter=145.6779082949793
# after update, this parameter=145.73579451190244
# difference = 0.057886216923151323
#
#
# Now descent
# gradient with respect to c1 = -0.011566788255645832
# grad=-0.011566788255645832 <0, move forward
# before update, this parameter=145.73579451190244
# after update, this parameter=145.79362845318067
# difference = 0.057833941278232714
#
#
# Now descent
# gradient with respect to c1 = -0.011556980960225616
# grad=-0.011556980960225616 <0, move forward
# before update, this parameter=145.79362845318067
# after update, this parameter=145.8514133579818
# difference = 0.05778490480113874
#
#
# Now descent
# gradient with respect to c1 = -0.011541322072039506
# grad=-0.011541322072039506 <0, move forward
# before update, this parameter=145.8514133579818
# after update, this parameter=145.909119968342
# difference = 0.057706610360185095
#
#
# Now descent
# gradient with respect to c1 = -0.011533368185601134
# grad=-0.011533368185601134 <0, move forward
# before update, this parameter=145.909119968342
# after update, this parameter=145.96678680927
# difference = 0.057666840927993235
#
#
# Now descent
# gradient with respect to c1 = -0.01152513724944626
# grad=-0.01152513724944626 <0, move forward
# before update, this parameter=145.96678680927
# after update, this parameter=146.02441249551723
# difference = 0.05762568624723485
#
#
# Now descent
# gradient with respect to c1 = -0.011513274433383458
# grad=-0.011513274433383458 <0, move forward
# before update, this parameter=146.02441249551723
# after update, this parameter=146.08197886768414
# difference = 0.05756637216691729
#
#
# Now descent
# gradient with respect to c1 = -0.011509537657605762
# grad=-0.011509537657605762 <0, move forward
# before update, this parameter=146.08197886768414
# after update, this parameter=146.13952655597217
# difference = 0.057547688288025256
#
#
# Now descent
# gradient with respect to c1 = -0.011495341795786373
# grad=-0.011495341795786373 <0, move forward
# before update, this parameter=146.13952655597217
# after update, this parameter=146.1970032649511
# difference = 0.05747670897892476
#
#
# Now descent
# gradient with respect to c1 = -0.011477727066999677
# grad=-0.011477727066999677 <0, move forward
# before update, this parameter=146.1970032649511
# after update, this parameter=146.2543919002861
# difference = 0.057388635335001936
#
#
# Now descent
# gradient with respect to c1 = -0.011468605361386608
# grad=-0.011468605361386608 <0, move forward
# before update, this parameter=146.2543919002861
# after update, this parameter=146.31173492709303
# difference = 0.05734302680693304
#
#
# Now descent
# gradient with respect to c1 = -0.011459816464221007
# grad=-0.011459816464221007 <0, move forward
# before update, this parameter=146.31173492709303
# after update, this parameter=146.36903400941412
# difference = 0.057299082321094374
#
#
# Now descent
# gradient with respect to c1 = -0.011439827477532916
# grad=-0.011439827477532916 <0, move forward
# before update, this parameter=146.36903400941412
# after update, this parameter=146.4262331468018
# difference = 0.05719913738766991
#
#
# Now descent
# gradient with respect to c1 = -0.011435646134927424
# grad=-0.011435646134927424 <0, move forward
# before update, this parameter=146.4262331468018
# after update, this parameter=146.48341137747644
# difference = 0.05717823067465133
#
#
# Now descent
# gradient with respect to c1 = -0.011427329754454263
# grad=-0.011427329754454263 <0, move forward
# before update, this parameter=146.48341137747644
# after update, this parameter=146.5405480262487
# difference = 0.057136648772257104
#
#
# Now descent
# gradient with respect to c1 = -0.011416172734035612
# grad=-0.011416172734035612 <0, move forward
# before update, this parameter=146.5405480262487
# after update, this parameter=146.59762888991887
# difference = 0.05708086367016563
#
#
# Now descent
# gradient with respect to c1 = -0.011404873543119365
# grad=-0.011404873543119365 <0, move forward
# before update, this parameter=146.59762888991887
# after update, this parameter=146.65465325763446
# difference = 0.0570243677155986
#
#
# Now descent
# gradient with respect to c1 = -0.011396719824308121
# grad=-0.011396719824308121 <0, move forward
# before update, this parameter=146.65465325763446
# after update, this parameter=146.711636856756
# difference = 0.056983599121537054
#
#
# Now descent
# gradient with respect to c1 = -0.011385119760731754
# grad=-0.011385119760731754 <0, move forward
# before update, this parameter=146.711636856756
# after update, this parameter=146.76856245555967
# difference = 0.05692559880367298
#
#
# Now descent
# gradient with respect to c1 = -0.011376317604394615
# grad=-0.011376317604394615 <0, move forward
# before update, this parameter=146.76856245555967
# after update, this parameter=146.82544404358165
# difference = 0.05688158802198018
#
#
# Now descent
# gradient with respect to c1 = -0.01136510658383827
# grad=-0.01136510658383827 <0, move forward
# before update, this parameter=146.82544404358165
# after update, this parameter=146.88226957650085
# difference = 0.056825532919191346
#
#
# Now descent
# gradient with respect to c1 = -0.011356322897393412
# grad=-0.011356322897393412 <0, move forward
# before update, this parameter=146.88226957650085
# after update, this parameter=146.9390511909878
# difference = 0.05678161448696528
#
#
# Now descent
# gradient with respect to c1 = -0.011344911783117695
# grad=-0.011344911783117695 <0, move forward
# before update, this parameter=146.9390511909878
# after update, this parameter=146.9957757499034
# difference = 0.05672455891559025
#
#
# Now descent
# gradient with respect to c1 = -0.011332142925590816
# grad=-0.011332142925590816 <0, move forward
# before update, this parameter=146.9957757499034
# after update, this parameter=147.05243646453135
# difference = 0.0566607146279523
#
#
# Now descent
# gradient with respect to c1 = -0.011323252895101277
# grad=-0.011323252895101277 <0, move forward
# before update, this parameter=147.05243646453135
# after update, this parameter=147.10905272900686
# difference = 0.05661626447550816
#
#
# Now descent
# gradient with respect to c1 = -0.011313231499610055
# grad=-0.011313231499610055 <0, move forward
# before update, this parameter=147.10905272900686
# after update, this parameter=147.16561888650492
# difference = 0.056566157498053826
#
#
# Now descent
# gradient with respect to c1 = -0.011304249722066118
# grad=-0.011304249722066118 <0, move forward
# before update, this parameter=147.16561888650492
# after update, this parameter=147.22214013511524
# difference = 0.05652124861032348
#
#
# Now descent
# gradient with respect to c1 = -0.01129317042880551
# grad=-0.01129317042880551 <0, move forward
# before update, this parameter=147.22214013511524
# after update, this parameter=147.27860598725925
# difference = 0.056465852144015116
#
#
# Now descent
# gradient with respect to c1 = -0.011280410450398293
# grad=-0.011280410450398293 <0, move forward
# before update, this parameter=147.27860598725925
# after update, this parameter=147.33500803951125
# difference = 0.05640205225199679
#
#
# Now descent
# gradient with respect to c1 = -0.011271352075459262
# grad=-0.011271352075459262 <0, move forward
# before update, this parameter=147.33500803951125
# after update, this parameter=147.39136479988855
# difference = 0.05635676037729809
#
#
# Now descent
# gradient with respect to c1 = -0.011280446198913552
# grad=-0.011280446198913552 <0, move forward
# before update, this parameter=147.39136479988855
# after update, this parameter=147.4477670308831
# difference = 0.056402230994564206
#
#
# Now descent
# gradient with respect to c1 = -0.01125181811545417
# grad=-0.01125181811545417 <0, move forward
# before update, this parameter=147.4477670308831
# after update, this parameter=147.50402612146038
# difference = 0.056259090577270854
#
#
# Now descent
# gradient with respect to c1 = -0.011244054201942077
# grad=-0.011244054201942077 <0, move forward
# before update, this parameter=147.50402612146038
# after update, this parameter=147.5602463924701
# difference = 0.056220271009721046
#
#
# Now descent
# gradient with respect to c1 = -0.011228580679700784
# grad=-0.011228580679700784 <0, move forward
# before update, this parameter=147.5602463924701
# after update, this parameter=147.6163892958686
# difference = 0.056142903398495037
#
#
# Now descent
# gradient with respect to c1 = -0.011223612881305911
# grad=-0.011223612881305911 <0, move forward
# before update, this parameter=147.6163892958686
# after update, this parameter=147.67250736027512
# difference = 0.0561180644065189
#
#
# Now descent
# gradient with respect to c1 = -0.011210276523510032
# grad=-0.011210276523510032 <0, move forward
# before update, this parameter=147.67250736027512
# after update, this parameter=147.72855874289266
# difference = 0.0560513826175395
#
#
# Now descent
# gradient with respect to c1 = -0.01120448807401253
# grad=-0.01120448807401253 <0, move forward
# before update, this parameter=147.72855874289266
# after update, this parameter=147.78458118326273
# difference = 0.056022440370071536
#
#
# Now descent
# gradient with respect to c1 = -0.011193289647826177
# grad=-0.011193289647826177 <0, move forward
# before update, this parameter=147.78458118326273
# after update, this parameter=147.84054763150186
# difference = 0.05596644823913266
#
#
# Now descent
# gradient with respect to c1 = -0.01118334796768039
# grad=-0.01118334796768039 <0, move forward
# before update, this parameter=147.84054763150186
# after update, this parameter=147.89646437134027
# difference = 0.05591673983840906
#
#
# Now descent
# gradient with respect to c1 = -0.011171297718659545
# grad=-0.011171297718659545 <0, move forward
# before update, this parameter=147.89646437134027
# after update, this parameter=147.95232085993356
# difference = 0.0558564885932924
#
#
# Now descent
# gradient with respect to c1 = -0.011163717291040598
# grad=-0.011163717291040598 <0, move forward
# before update, this parameter=147.95232085993356
# after update, this parameter=148.00813944638878
# difference = 0.0558185864552172
#
#
# Now descent
# gradient with respect to c1 = -0.01115075624058548
# grad=-0.01115075624058548 <0, move forward
# before update, this parameter=148.00813944638878
# after update, this parameter=148.0638932275917
# difference = 0.05575378120292385
#
#
# Now descent
# gradient with respect to c1 = -0.011142513036688229
# grad=-0.011142513036688229 <0, move forward
# before update, this parameter=148.0638932275917
# after update, this parameter=148.11960579277513
# difference = 0.05571256518342693
#
#
# Now descent
# gradient with respect to c1 = -0.011134189351835744
# grad=-0.011134189351835744 <0, move forward
# before update, this parameter=148.11960579277513
# after update, this parameter=148.1752767395343
# difference = 0.05567094675916451
#
#
# Now descent
# gradient with respect to c1 = -0.011121547586423475
# grad=-0.011121547586423475 <0, move forward
# before update, this parameter=148.1752767395343
# after update, this parameter=148.23088447746642
# difference = 0.055607737932120926
#
#
# Now descent
# gradient with respect to c1 = -0.011112628101495048
# grad=-0.011112628101495048 <0, move forward
# before update, this parameter=148.23088447746642
# after update, this parameter=148.2864476179739
# difference = 0.05556314050747346
#
#
# Now descent
# gradient with respect to c1 = -0.011103971846226912
# grad=-0.011103971846226912 <0, move forward
# before update, this parameter=148.2864476179739
# after update, this parameter=148.34196747720503
# difference = 0.05551985923113989
#
#
# Now descent
# gradient with respect to c1 = -0.011091266765683727
# grad=-0.011091266765683727 <0, move forward
# before update, this parameter=148.34196747720503
# after update, this parameter=148.39742381103346
# difference = 0.05545633382843107
#
#
# Now descent
# gradient with respect to c1 = -0.011083359660490899
# grad=-0.011083359660490899 <0, move forward
# before update, this parameter=148.39742381103346
# after update, this parameter=148.4528406093359
# difference = 0.05541679830244561
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 7
#       3 params = initial_params
#       5 p= 'c1'
# ----> 7 gradient_descent_boosting1(params, p)
#
# Cell In[10], line 29, in gradient_descent_boosting1(params, p)
#      25 while not boosting:
#      27         descent+=1
# ---> 29         grad = gradient(current_params, index)
#      30         print('\n')
#      31         print('Now descent')
#
# Cell In[5], line 10, in gradient(current_params, index)
#       8 params_plus[index] += epsilon
#       9 params_minus[index] -= epsilon
# ---> 10 grad = (cost_function(params_plus) - cost_function(params_minus)) / (2 * epsilon)
#      12 return grad
#
# Cell In[4], line 8, in cost_function(params)
#       5 cost = 0
#       7 for P980, exp_nir in zip(P980_NIR, NIR_exp):
# ----> 8     nir = compute_NIR_for_x(x, P980, c1, c2, c3, c4, k31, k41, k51)
#       9     cost_NIR = ((nir - exp_nir)/exp_nir)**2
#      10     cost += cost_NIR
#
# Cell In[3], line 71, in compute_NIR_for_x(x, P980, c1, c2, c3, c4, k31, k41, k51)
#      69 state0 = [0, y, 0, 0, 0, 0]
#      70 t = np.arange(0.0, 0.001, 0.000001)
# ---> 71 state = odeint(system, state0, t, args=(x, P980, c1, c2, c3, c4, k31, k41, k51))
#      72 NIR = a31 * W3 * state[:, 3][-1]
#      74 return NIR
#
# File ~/anaconda3/lib/python3.11/site-packages/scipy/integrate/_odepack_py.py:242, in odeint(func, y0, t, args, Dfun, col_deriv, full_output, ml, mu, rtol, atol, tcrit, h0, hmax, hmin, ixpr, mxstep, mxhnil, mxordn, mxords, printmessg, tfirst)
#     240 t = copy(t)
#     241 y0 = copy(y0)
# --> 242 output = _odepack.odeint(func, y0, t, args, Dfun, col_deriv, ml, mu,
#     243                          full_output, rtol, atol, tcrit, h0, hmax, hmin,
#     244                          ixpr, mxstep, mxhnil, mxordn, mxords,
#     245                          int(bool(tfirst)))
#     246 if output[-1] < 0:
#     247     warning_msg = _msgs[output[-1]] + " Run with full_output = 1 to get quantitative information."
#
# KeyboardInterrupt:
